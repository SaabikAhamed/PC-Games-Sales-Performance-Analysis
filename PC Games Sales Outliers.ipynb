# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\Saabik Ahamed\\Downloads\\archive (3)\\Games.csv")

# %%
df.head()
# Out:
#                             Name Release  Quantity  Sales    Sales Type  \
# 0  PlayerUnknown's Battlegrounds  Dec-17       9.0   42.0    Wholesaler
# 1                      Minecraft  Nov-11      15.0   33.0        Online
# 2                     Diablo III  May-12       6.0   20.0  Direct Sales
# 3                    Garry's Mod  Nov-06       5.0   20.0  Direct Sales
# 4                       Terraria  May-11      12.0   17.2        Online
#
#                  Genre               Developer               Publisher  \
# 0        Battle royale            PUBG Studios                 Krafton
# 1    Sandbox, survival          Mojang Studios          Mojang Studios
# 2  Action role-playing  Blizzard Entertainment  Blizzard Entertainment
# 3              Sandbox       Facepunch Studios                   Valve
# 4     Action-adventure                Re-Logic                Re-Logic
#
#    Selling Price
# 0         103.88
# 1         142.80
# 2          80.94
# 3          48.84
# ...

# %%
df.describe()
# Out:
#          Quantity       Sales  Selling Price
# count  175.000000  175.000000     175.000000
# mean     7.560000    3.141143      94.016457
# std      4.209404    4.960513      53.978496
# min      1.000000    1.000000       6.700000
# 25%      4.000000    1.000000      49.025000
# 50%      7.000000    1.500000      85.760000
# 75%     11.000000    3.000000     142.800000
# max     15.000000   42.000000     210.000000

# %%
# USING Z-SCORE METHOD TO IDENTIFY THE OUTLIERS

upper_limit = df['Sales'].mean() + 3*df['Sales'].std()
lower_limit = df['Sales'].mean() - 3*df['Sales'].std()
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 18.02268159054985
# lower limit: -11.740395876264138

# %%
# FIND THE OUTLIERS

df.loc[(df['Sales'] > upper_limit) | (df['Sales'] < lower_limit)]
# Out:
#                             Name Release  Quantity  Sales    Sales Type  \
# 0  PlayerUnknown's Battlegrounds  Dec-17       9.0   42.0    Wholesaler
# 1                      Minecraft  Nov-11      15.0   33.0        Online
# 2                     Diablo III  May-12       6.0   20.0  Direct Sales
# 3                    Garry's Mod  Nov-06       5.0   20.0  Direct Sales
#
#                  Genre               Developer               Publisher  \
# 0        Battle royale            PUBG Studios                 Krafton
# 1    Sandbox, survival          Mojang Studios          Mojang Studios
# 2  Action role-playing  Blizzard Entertainment  Blizzard Entertainment
# 3              Sandbox       Facepunch Studios                   Valve
#
#    Selling Price
# 0         103.88
# 1         142.80
# 2          80.94
# 3          48.84

# %%
# TO SEE THE OUTLIERS CLEARLY

sns.boxplot(df['Sales'])
# Out:
# <Axes: >
